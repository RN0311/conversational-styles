# %% [markdown]
# <a href="https://colab.research.google.com/github/dgbrizan/conversationalstyles/blob/main/EDA_on_final_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('/content/all-features-with-pause-and-target.csv')
df.tail()
# Out:
#         Unnamed: 0  start time  ...  education      pause
# 115455      115455  148.062625  ...          2  32.315125
# 115456      115456  150.580750  ...          2   8.003500
# 115457      115457  168.979125  ...          2   7.356750
# 115458      115458  174.996375  ...          2  26.131500
# 115459      115459  179.028250  ...          2   5.242625
#
# [5 rows x 18 columns]

# %%
old_df.to_csv("data-for-visualization.csv")

# %%
df.drop(['Unnamed: 0', 'sentence', ' generation_description'], axis=1, inplace=True)
#df.columns

# %%
df.columns
# Out:
# Index(['start time', 'end time', 'speech rate', 'utterance', 'repitition',
#        'pronoun rate', 'loudness', 'pitch', 'speaker', 'generation_decade',
#        'gender', 'region', 'generation_year', 'education', 'pause'],
#       dtype='object')

# %%
old_df.to_csv('preprocessedData.csv', index=False)

# %%
import pandas as pd

old_df = pd.read_csv('/content/out.csv')
old_df.tail()
# Out:
#         start time   end time  ...  education      pause
# 115455  148.062625  150.58075  ...          2  32.315125
# 115456  150.580750  152.27100  ...          2   8.003500
# 115457  168.979125  171.09875  ...          2   7.356750
# 115458  174.996375  179.02825  ...          2  26.131500
# 115459  179.028250  186.49175  ...          2   5.242625
#
# [5 rows x 15 columns]

# %%
indexNames = old_df[ old_df['repitition'] == 0 ].index
old_df.drop(indexNames , inplace=True)

# %%
indexNames = old_df[ old_df['pause'] > 100 ].index
old_df.drop(indexNames , inplace=True)

# %%
indexNames = old_df[ old_df['pause'] == 0 ].index
old_df.drop(indexNames , inplace=True)

# %%
indexNames = old_df[ old_df['pitch'] > 600 ].index
old_df.drop(indexNames , inplace=True)

# %%
indexNames = old_df[ old_df['pitch'] == 0 ].index
old_df.drop(indexNames , inplace=True)

# %%
indexNames = old_df[ old_df['pronoun rate'] == 1 ].index
old_df.drop(indexNames , inplace=True)

# %%
indexNames = old_df[ old_df['speech rate'] > 80 ].index
old_df.drop(indexNames , inplace=True)

# %%
from numpy.lib.function_base import average
average(old_df.pitch)
# Out:
# 173.19617876320808

# %%
#old_df = old_df.drop_duplicates(subset = ["speaker"])
old_df['pause'] = ""

# %%
df7['pause'] = df7['pause'].round(2)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df7.tail()
# Out:
#         start time    end time  speech rate  ...  generation_year  education  pause
# 115431  216.061250  218.355250        37.49  ...             1944          3  11.98
# 115432  218.355250  224.445875        14.12  ...             1944          3   6.50
# 115433  224.445875  229.988750        15.52  ...             1944          3  15.56
# 115434  233.079750  235.438125        36.47  ...             1944          3  18.50
# 115435  235.438125  237.005000        54.89  ...             1944          3  19.20
#
# [5 rows x 15 columns]

# %%
old_df = df7

# %%
old_df['pause'] = old_df['pause'].fillna(0)

# %%
old_df['pause'] = old_df['pause'].clip(lower=0)

# %%
min(old_df['pause'])
# Out:
# 0.0

# %%
import matplotlib.pyplot as plt

# Single distribution
n_bins = 100
plt.hist(old_df['pitch'], bins=n_bins)
plt.xlabel('pitch')
plt.show()

# %%
import matplotlib.pyplot as plt

# Single distribution
n_bins = 200
plt.hist(old_df['repitition'], bins=n_bins)
plt.xlabel('pause')
plt.show()

# %%
import seaborn as sns

# %%
sns.swarmplot(old_df.sample(1000).pitch)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 68.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
import matplotlib as plt
from matplotlib import rcParams
sns.set(font_scale = 1.5)
rcParams['figure.figsize'] = 13,10
sns.set_style("darkgrid")
colors = ["g", "o"]
sns.swarmplot(x = 'gender', y = 'pitch', data = old_df.sample(1000))

# %%
old_df.head()
# Out:
#     speech rate  utterance  repitition  ...  generation_year  education  pause
# 43        69.33        0.0           5  ...             1959          3  18.28
# 44         6.01       35.0         106  ...             1959          3  17.37
# 45        52.00        0.0           5  ...             1959          3   6.51
# 46        44.37        0.0           4  ...             1959          3  11.70
# 47        36.41        0.0           7  ...             1959          3   6.24
#
# [5 rows x 12 columns]

# %%
import seaborn as sns
import matplotlib as plt
import numpy as np
from matplotlib import rcParams

rcParams['figure.figsize'] = 13,10
sns.set_style("darkgrid")
#sns.swarmplot(x = 'region', y = 'gender', data = old_df.sample(1000))
#sns.boxplot(x="repitition", y="education", data=old_df.sample(1000), whis=np.inf)
sns.swarmplot(x = 'gender', y = 'pronoun rate', data = old_df.sample(1000))
#sns.swarmplot(x="pronoun rate", y="education", data=old_df, color=".2")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 25.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 29.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
rcParams['figure.figsize'] = 12,14
sns.violinplot(x = 'gender', y = 'pronoun rate', data = old_df.sample(100), inner=None)
sns.swarmplot(x = 'gender', y = 'pronoun rate', data = old_df.sample(100), color="white", edgecolor="gray")

# %%
rcParams['figure.figsize'] = 12,14
sns.violinplot(x = 'gender', y = 'speech rate', data = old_df.sample(100), inner=None)
sns.swarmplot(x = 'gender', y = 'speech rate', data = old_df.sample(100), color="white", edgecolor="gray")

# %%
indexNames = old_df[ old_df['pitch'] > 500 ].index

# %%
indexNames = old_df[ old_df['pitch'] == 0 ].index

# %%
indexNames
# Out:
# Int64Index([    49,     56,     79,     93,    124,    176,    178,    229,
#                258,    645,
#             ...
#             113033, 113037, 113038, 113480, 113491, 113493, 114036, 114078,
#             114080, 114835],
#            dtype='int64', length=1048)

# %%
old_df.drop(indexNames , inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
import matplotlib.pyplot as plt

# Single distribution
n_bins = 100
rcParams['figure.figsize'] = 14,12
for gender in old_df['gender'].unique():
    g_df = old_df[old_df['gender']== gender]
    plt.hist(g_df.pitch, label=gender, bins=n_bins, alpha=0.5)
plt.xlabel('pitch')
plt.ylabel('Count of people')
plt.legend()
plt.show()

# %%
#old_df.drop(columns = ['start time', 'end time'], axis=1, inplace=True)
old_df.drop(columns = ['generation_decade'], axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
old_df.columns
# Out:
# Index(['speech rate', 'utterance', 'repitition', 'pronoun rate', 'loudness',
#        'pitch', 'speaker', 'gender', 'region', 'generation_year', 'education',
#        'pause'],
#       dtype='object')

# %%
import seaborn as sns
sns.pairplot(old_df)

# %%
import matplotlib.pyplot as plt

# Single distribution
n_bins = 100
plt.hist(old_df['speech rate'], bins=n_bins)
plt.xlabel('speech rate')
plt.show()

# %%
n_bins = 100
for gender in old_df['gender'].unique():
    g_df = old_df[old_df['gender']== gender]
    plt.hist(old_df['speech rate'], label=gender, bins=n_bins, alpha=0.5)
plt.xlabel('speech rate')
plt.ylabel('Count of people')
plt.legend()
plt.show()

# %%
for i in range(1,len(old_df['start time'])):
    old_df['pause'].iloc[i] = old_df['start time'].iloc[i]-old_df['end time'].iloc[i-1]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
old_df.to_csv("all-features-with-pause-and-target.csv")

# %%
old_df['pause'] = old_df['pause'].replace(np.nan, 0)

# %%
old_df['pause'] = old_df['pause'].fillna(0)

# %%
by_group = old_df.groupby(old_df.speaker)

old_df['pause'] = list(by_group.apply(lambda x: x['end time']-x['start time'].shift()))

# %%
old_df['region'].unique()
# Out:
# array([' southern', ' south_midland', ' northern', ' western', ' nyc',
#        ' north_midland', ' mixed', ' new_england', ' unk'], dtype=object)

# %%
max(old_df.pitch)
# Out:
# 2093.0

# %%
old_df.columns
# Out:
# Index(['start time', 'end time', 'speech rate', 'utterance', 'repitition',
#        'pronoun rate', 'loudness', 'pitch', 'speaker', 'generation_decade',
#        'gender', 'region', 'generation_year', 'education', 'pause'],
#       dtype='object')

# %%
old_df['region'].unique()
# Out:
# array([' southern', ' south_midland', ' northern', ' western', ' nyc',
#        ' north_midland', ' mixed', ' new_england', ' unk'], dtype=object)

# %%
# nyc male, vs western female
df1 = old_df[old_df['region'] != ' new_england']

# %%
# nyc male, vs western female
df2 = df1[df1['region'] != ' northern']

# %%
# nyc male, vs western female
df3 = df2[df2['region'] != ' southern']

# %%
# nyc male, vs western female
df4 = df3[df3['region'] != ' mixed']

# %%
# nyc male, vs western female
df5 = df4[df4['region'] != ' unk']

# %%
# nyc male, vs western female
df6 = df5[df5['region'] != ' south_midland']

# %%
# nyc male, vs western female
df7 = df6[df6['region'] != ' north_midland']

# %%
#make a copy of regionally transformed dataset, so that you can engineer gender values and take groupby on its copy
copy_df = df7

# %%
new_df = df7

# %%
new_df.columns
# Out:
# Index(['start time', 'end time', 'speech rate', 'utterance', 'repitition',
#        'pronoun rate', 'loudness', 'pitch', 'speaker', 'generation_decade',
#        'gender', 'region', 'generation_year', 'education', 'pause',
#        'duration'],
#       dtype='object')

# %%
new_df['duration'] = new_df['end time'] - new_df['start time']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
from collections import defaultdict
unique_values = new_df['speaker'].unique()
gender_labels = defaultdict(int)
#region_labels = defaultdict(int)
for i in range(len(unique_values)):
  gender_labels[unique_values[i]] = new_df['gender'][new_df['speaker'] == unique_values[i]].values[0]
  #region_labels[unique_values[i]] = df['region'][df['speaker'] == unique_values[i]].values[0]

# %%
new_df = df7.groupby(['speaker']).mean().reset_index()

# %%
new_df.head()
# Out:
#              speaker  start time    end time  ...  education      pause  duration
# 0   Switchboard.1001  140.526639  145.937388  ...        3.0  13.669517  5.410749
# 1   Switchboard.1005  235.736340  241.398975  ...        2.0  14.625523  5.662635
# 2   Switchboard.1028  252.814180  257.712381  ...        3.0  13.803118  4.898202
# 3   Switchboard.1045  242.195352  246.697146  ...        2.0  12.549387  4.501794
# 4   Switchboard.1052  263.084776  267.422513  ...        2.0  12.975671  4.337737
#
# [5 rows x 13 columns]

# %%
gl = pd.DataFrame(gender_labels.items(), columns=['speaker', 'gender'])

# %%
labels_df = pd.merge(new_df, gl, on='speaker')

# %%
labels_df.head()
# Out:
#              speaker  start time    end time  ...      pause  duration   gender
# 0   Switchboard.1001  140.526639  145.937388  ...  13.669517  5.410749     male
# 1   Switchboard.1005  235.736340  241.398975  ...  14.625523  5.662635   female
# 2   Switchboard.1028  252.814180  257.712381  ...  13.803118  4.898202     male
# 3   Switchboard.1045  242.195352  246.697146  ...  12.549387  4.501794   female
# 4   Switchboard.1052  263.084776  267.422513  ...  12.975671  4.337737     male
#
# [5 rows x 14 columns]

# %%
new_df = labels_df

# %%
new_df.tail()
# Out:
#                speaker  start time    end time  ...      pause  duration   gender
# 102   Switchboard.1655  151.344216  154.809864  ...  13.118966  3.465648     male
# 103   Switchboard.1660  129.796527  135.808812  ...  19.766080  6.012286   female
# 104   Switchboard.1680  130.831278  137.459500  ...  13.767862  6.628222   female
# 105   Switchboard.1690  140.320341  144.130433  ...  17.092572  3.810091     male
# 106   Switchboard.1697  128.002588  134.876246  ...  14.710742  6.873658   female
#
# [5 rows x 14 columns]

# %%
new_df.drop(['speaker', 'generation_year', 'education', 'start time', 'end time'], axis=1, inplace=True)
new_df.tail()
# Out:
#      speech rate  utterance  repitition  ...      pause  duration   gender
# 102    40.857273   7.090909   29.636364  ...  13.118966  3.465648     male
# 103    24.144286  17.000000   50.642857  ...  19.766080  6.012286   female
# 104    18.840269  20.715054   56.134409  ...  13.767862  6.628222   female
# 105    31.130769   9.500000   20.730769  ...  17.092572  3.810091     male
# 106    20.298000  20.766667   50.566667  ...  14.710742  6.873658   female
#
# [5 rows x 9 columns]

# %%
new_df.drop(['speaker', 'generation_year', 'education', 'start time', 'end time'], axis=1, inplace=True)
new_df.tail()
# Out:
#      speech rate  utterance  repitition  ...       pitch  duration   gender
# 102    49.618235   4.882353   22.352941  ...  200.445882  2.764838     male
# 103    22.950000  18.800000   56.266667  ...  170.721333  6.532358   female
# 104    20.489516  19.423387   52.983871  ...  244.492500  6.331837   female
# 105    41.551190   7.214286   17.500000  ...   75.756190  3.191670     male
# 106    22.038286  19.857143   47.057143  ...  193.449429  6.589061   female
#
# [5 rows x 8 columns]

# %%
new_df.columns
# Out:
# Index(['speech rate', 'utterance', 'repitition', 'pronoun rate', 'loudness',
#        'pitch', 'pause', 'duration', 'gender'],
#       dtype='object')

# %%
df_one = pd.get_dummies(new_df["gender"])
 
# Binary Data is Concatenated into Dataframe
df_two = pd.concat((df_one, new_df), axis=1)
 
# Gendercolumn is dropped
#df_two = df_two.drop(["gender"], axis=1)
 
# We want Male =0 and Female =1 So we drop Male column here
#df_two = df_two.drop([" male"], axis=1)
 
# Rename the Column
#result = df_two.rename(columns={" female": "gender"})

# %%
df_two.drop(["gender", " male"], axis=1, inplace=True)

df_two.head()
# Out:
#     female  speech rate  utterance  ...       pitch      pause  duration
# 0        0    23.065342  12.773973  ...  127.461918  13.669517  5.410749
# 1        1    26.613977  17.060519  ...  216.903055  14.625523  5.662635
# 2        0    27.740951  15.622877  ...  142.764949  13.803118  4.898202
# 3        1    28.295904  11.759036  ...  203.413253  12.549387  4.501794
# 4        0    26.589854  10.283981  ...  119.247549  12.975671  4.337737
#
# [5 rows x 9 columns]

# %%
df_two = df_two.rename(columns={" female": "gender"})

# %%
new_df = df_two

# %%
df_two.columns
# Out:
# Index(['gender', 'speech rate', 'utterance', 'repitition', 'pronoun rate',
#        'loudness', 'pitch', 'pause', 'duration'],
#       dtype='object')

# %%
column_names = ['speech rate', 'utterance', 'repitition', 'pronoun rate', 'loudness',
       'pitch', 'duration', 'pause', 'gender']

new_df = new_df.reindex(columns=column_names)

# %%
new_df.head()
# Out:
#    speech rate  utterance  repitition  ...       pitch  duration      pause
# 0    23.065342  12.773973   32.424658  ...  127.461918  5.410749  13.669517
# 1    26.613977  17.060519   42.778098  ...  216.903055  5.662635  14.625523
# 2    27.740951  15.622877   40.325028  ...  142.764949  4.898202  13.803118
# 3    28.295904  11.759036   32.072289  ...  203.413253  4.501794  12.549387
# 4    26.589854  10.283981   27.881068  ...  119.247549  4.337737  12.975671
#
# [5 rows x 8 columns]

# %%
#new_df.drop(['speaker','generation_year', 'education', 'start time', 'end time'], axis=1, inplace=True)
new_df.tail()
# Out:
#      speech rate  utterance  repitition  ...  duration      pause  gender
# 102    40.857273   7.090909   29.636364  ...  3.465648  13.118966       0
# 103    24.144286  17.000000   50.642857  ...  6.012286  19.766080       1
# 104    18.840269  20.715054   56.134409  ...  6.628222  13.767862       1
# 105    31.130769   9.500000   20.730769  ...  3.810091  17.092572       0
# 106    20.298000  20.766667   50.566667  ...  6.873658  14.710742       1
#
# [5 rows x 9 columns]

# %%
new_df['gender'].unique()
# Out:
# array([0, 1], dtype=uint8)

# %%
genderlabel = new_df['gender']
new_df = new_df.drop(columns=['gender'])

# %%
df_two.head()
# Out:
#    gender  speech rate  utterance  ...       pitch     pause  duration
# 0       0    24.891146  12.036458  ...  131.619740  5.944781  5.267169
# 1       1    28.838811  16.131148  ...  217.414672  7.418936  5.386516
# 2       0    29.572070  15.323038  ...  154.654683  5.839303  4.809621
# 3       1    30.519688  11.104167  ...  201.863437  6.831705  4.299965
# 4       0    28.087120  10.011200  ...  141.893184  5.765210  4.292630
#
# [5 rows x 9 columns]

# %%
#importing libraries
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = new_df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
copy_df.head()
# Out:
#    speech rate  utterance  repitition  ...  duration      pause  gender
# 0    23.065342  12.773973   32.424658  ...  5.410749  13.669517       0
# 1    26.613977  17.060519   42.778098  ...  5.662635  14.625523       1
# 2    27.740951  15.622877   40.325028  ...  4.898202  13.803118       0
# 3    28.295904  11.759036   32.072289  ...  4.501794  12.549387       1
# 4    26.589854  10.283981   27.881068  ...  4.337737  12.975671       0
#
# [5 rows x 9 columns]

# %%
copy_df = ref

# %%
without_pause_df = copy_df.drop(['pause'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-229-e558272e028c> in <module>()
# ----> 1 without_pause_df = copy_df.drop(['pause'], axis=1, inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
ref.head()
# Out:
#    speech rate  utterance  repitition  ...       pitch  duration  gender
# 0    23.065342  12.773973   32.424658  ...  127.461918  5.410749       0
# 1    26.613977  17.060519   42.778098  ...  216.903055  5.662635       1
# 2    27.740951  15.622877   40.325028  ...  142.764949  4.898202       0
# 3    28.295904  11.759036   32.072289  ...  203.413253  4.501794       1
# 4    26.589854  10.283981   27.881068  ...  119.247549  4.337737       0
#
# [5 rows x 8 columns]

# %%
copy_df = without_pause_df

# %%
#Correlation with output variable : gender
cor_target = abs(cor['gender'])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.1]
relevant_features
# Out:
# pronoun rate    0.159001
# loudness        0.180586
# pitch           0.875547
# gender          1.000000
# Name: gender, dtype: float64

# %%
from collections import defaultdict
#unique_values = new_df['speaker'].unique()
gender_labels = defaultdict(int)
region_labels = defaultdict(int)
generation_year = defaultdict(int)
generation_description = defaultdict(int)

for i in range(len(unique_values)):
  gender_labels[unique_values[i]] = copy_df['gender'][copy_df['speaker'] == unique_values[i]].values[0]
  region_labels[unique_values[i]] = copy_df['region'][copy_df['speaker'] == unique_values[i]].values[0]
  generation_year[unique_values[i]] = old_df['generation_year'][old_df['speaker'] == unique_values[i]].values[0]
  generation_description[unique_values[i]] = old_df[' generation_description'][old_df['speaker'] == unique_values[i]].values[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'speaker'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
gl = pd.DataFrame(gender_labels.items(), columns=['speaker', 'gender'])

# %%
rl = pd.DataFrame(region_labels.items(), columns=['speaker', 'region'])

# %%
labels_df = pd.merge(gl, rl, on='speaker')

# %%
new_df.drop(['gender'], axis=1, inplace=True)

# %%
#PCA
from sklearn.preprocessing import StandardScaler
import numpy as np

final_df = pd.DataFrame(StandardScaler().fit_transform(new_df.values), 
                  columns=['speech rate', 'utterance', 'repitition', 'pronoun rate', 'loudness',
       'pitch', 'duration'])
final_df.head()
# Out:
#    speech rate  utterance  repitition  ...  loudness     pitch  duration
# 0    -0.698310  -0.196507   -0.366842  ...  0.485414 -0.787358  0.220175
# 1    -0.040203   0.891107    0.691167  ...  1.294024  1.209771  0.460370
# 2     0.168799   0.526338    0.440490  ...  0.106261 -0.445657 -0.268584
# 3     0.271717  -0.454024   -0.402850  ... -0.428733  0.908558 -0.646594
# 4    -0.044677  -0.828286   -0.831147  ... -0.002096 -0.970776 -0.803036
#
# [5 rows x 7 columns]

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

pca = PCA().fit(final_df)
evr = pca.explained_variance_ratio_

plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.ylim(0., 1.) 
plt.xlabel('Number of Components')
plt.ylabel('Total Explained Variance')
# Out:
# Text(0, 0.5, 'Total Explained Variance')

# %%
evr
# Out:
# array([0.53983185, 0.17013864, 0.12500828, 0.11404835, 0.03776195,
#        0.00807808, 0.00513285])

# %%
import seaborn as sns
import plotly.express as px
sns.set(rc = {'figure.figsize':(15,8)})

# %%
pca = PCA(n_components=2)
pc = pca.fit_transform(final_df)

#pc_df = pd.DataFrame(data = pc, columns = ['principal component 1', 'principal component 2', 'principal component 3'])
pc_df = pd.DataFrame(data = pc, columns = ['principal component 1', 'principal component 2'])

# %%
fig = px.scatter_3d(pc_df, x='principal component 1', y='principal component 2', z='principal component 3', labels=df_two['gender'], color = df_two['gender'])

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_3d(pc_df, x='principal component 1', y='principal component 2', z='principal component 3', labels=labels_df['region'], color = labels_df['region'])

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0ed78759-8de9-4b5e-a6b8-b4c8dce72c5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0ed78759-8de9-4b5e-a6b8-b4c8dce72c5a")) {
#                     Plotly.newPlot(
#                         '0ed78759-8de9-4b5e-a6b8-b4c8dce72c5a',
# ...

# %%
print(abs(pca.components_ ))
# Out:
# [[0.45283835 0.49123345 0.4834798  0.15842089 0.20012596 0.01155005
#   0.49766899 0.08318051]
#  [0.24084032 0.08842655 0.17901418 0.65793206 0.47262426 0.45791418
#   0.01959137 0.1892435 ]
#  [0.03689965 0.02838871 0.02781115 0.14453368 0.4034753  0.51688894
#   0.00811918 0.73901058]]

# %%
#Calculate/find the features which are important; feature importance, in the distribution format; Deborah Tannen said New York has higher involv style; Californian friends has high HC; are all HI vs HC : need some metrics too verify

# %%
def biplot(score, coeff , y):
    '''
    Author: Serafeim Loukas, serafeim.loukas@epfl.ch
    Inputs:
       score: the projected data
       coeff: the eigenvectors (PCs)
       y: the class labels
   '''
    xs = score[:,0] # projection on PC1
    ys = score[:,1] # projection on PC2
    n = coeff.shape[0] # number of variables
    plt.figure(figsize=(20,15), dpi=200)
    classes = np.unique(y)
    colors = ['g','r','y']
    markers=['o','o','x']
    features_label = {
        "1":"speech rate", 
        "2":"utterance", 
        "3":"repitition", 
        "4":"pronoun rate", 
        "5":"loudness", 
        "6":"pitch",
        "7":"duration",
        "8":"pause"}
    for s,l in enumerate(classes):
        plt.scatter(xs[y==l],ys[y==l], c = colors[s], marker=markers[s]) # color based on group
    for i in range(n):
        #plot as arrows the variable scores (each variable has a score for PC1 and one for PC2)
        plt.arrow(0, 0, coeff[i,0], coeff[i,1], color = 'k', alpha = 0.9,linestyle = '-',linewidth = 1.5, overhang=0.2)
        plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, features_label[str(i+1)], color = 'k', ha = 'center', va = 'center',fontsize=10)

    plt.xlabel("PC{}".format(1), size=14)
    plt.ylabel("PC{}".format(2), size=14)
    limx= int(xs.max()) + 1
    limy= int(ys.max()) + 1
    plt.xlim([-limx,limx])
    plt.ylim([-limy,limy])
    plt.grid()
    plt.tick_params(axis='both', which='both', labelsize=14)

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault) # reset ggplot style
# Call the biplot function for only the first 3 PCs
biplot(pc[:,0:2], np.transpose(pca.components_[0:2, :]), df_two['gender'])
plt.show()

# %%
np.corrcoef(final_df.iloc[:,3], final_df.iloc[:,5])[1,0]
# Out:
# 0.07968835229895557

# %%
final_df.head()
# Out:
#    speech rate  utterance  repitition  ...     pitch  duration     pause
# 0    -0.735143  -0.206461   -0.340483  ... -0.781362  0.284853  0.096707
# 1    -0.057441   0.864555    0.600137  ...  0.853101  0.402056  0.315299
# 2     0.068438   0.653184    0.485350  ... -0.342528 -0.164476  0.081066
# 3     0.231117  -0.450313   -0.446045  ...  0.556837 -0.664976  0.228223
# 4    -0.186485  -0.736191   -0.785778  ... -0.585645 -0.672179  0.070079
#
# [5 rows x 8 columns]

# %%
def biplot(score, coeff , y):
    '''
    Author: Serafeim Loukas, serafeim.loukas@epfl.ch
    Inputs:
       score: the projected data
       coeff: the eigenvectors (PCs)
       y: the class labels
   '''
    xs = score[:,0] # projection on PC1
    ys = score[:,1] # projection on PC2
    n = coeff.shape[0] # number of variables
    plt.figure(figsize=(10,9), dpi=200)
    classes = np.unique(y)
    colors = ['C1','C2','C3']
    markers=['o','o','o']
    features_label = {
        "1":"speech rate", 
        "2":"utterance", 
        "3":"repitition", 
        "4":"pronoun rate", 
        "5":"loudness", 
        "6":"\n \n pitch",
        "7":"duration"}
    for s,l in enumerate(classes):
        plt.scatter(xs[y==l],ys[y==l], c = colors[s], marker=markers[s]) # color based on group
    for i in range(n):
        #plot as arrows the variable scores (each variable has a score for PC1 and one for PC2)
        plt.arrow(0, 0, coeff[i,0], coeff[i,1], color = 'k', alpha = 0.6,linestyle = '-',linewidth = 1, overhang=0.1, head_width = 0.09)
        plt.text(coeff[i,0]* 1.2, coeff[i,1] * 1.5, features_label[str(i+1)], color = 'k', ha = 'right', va = 'center',fontsize=7)

    plt.xlabel("Principle Component {}".format(1), size=10)
    plt.ylabel("Principle Component {}".format(2), size=10)
    limx= int(xs.max()) + 0.1
    limy= int(ys.max()) + 0.5
    plt.xlim([-limx,limx])
    plt.ylim([-limy,limy])
    plt.grid()
    plt.legend(labels=["Male","Female"])
    plt.tick_params(axis='both', which='both', labelsize=10)
    plt.savefig("Biplot.png", bbox_inches='tight')

# %%
import matplotlib as mpl
import numpy as np
#mpl.rcParams.update(mpl.rcParamsDefault) # reset ggplot style
# Call the biplot function for only the first 3 PCs
biplot(pc[:,0:2], np.transpose(pca.components_[0:2, :]), df_two['gender'])
plt.show()

# %%
plt.savefig('Biplot.png')

# %%
pca_scores = PCA().fit_transform(X_st)
cluster.biplot(cscore=pca_scores, loadings=loadings, labels=X.columns.values, var1=round(pca_out.explained_variance_ratio_[0]*100, 2),
    var2=round(pca_out.explained_variance_ratio_[1]*100, 2), colorlist=target)
